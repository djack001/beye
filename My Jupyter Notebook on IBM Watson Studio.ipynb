# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>David Jack</b> <br> Innovator

# %% [markdown]
# *I am interested in data science because I am curious and like to solve problems.*

# %% [markdown]
# ### This code is supposed to show caluclation of "a" and "b" variables.

# %%
a = 24
b = 4

print (a+b)
print(a*b)
print(a/b)
# Out:
# 28
# 96
# 6.0

# %% [markdown]
# - - - <br>
# * bullet 1 <br>
# 1. item
# 2. item
# 3. item <br>
# ![image-2.JPG](attachment:image-2.JPG)<br>
# IBM Cloud (https://dataplatform.cloud.ibm.com/)
#
#
# | Name | Quantity | Price |
# | :- | -: | :-: |
# | Apple | 4       | $4    |
